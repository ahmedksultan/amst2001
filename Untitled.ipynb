# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
buildings_df = pd.read_csv('data/buildings.csv', dtype=object, keep_default_na=False)

# %%
buildings_df
# Out:
#                                                   Name     Category  \
# 0                       104 West! (Kosher Dining Hall)       Co-ops
# 1                                         112 Edgemoor       Co-ops
# 2                                       120 Maple Ave.  Near Campus
# 3                                     301 College Ave.  Collegetown
# 4                                     309 College Ave.  Collegetown
# ..                                                 ...          ...
# 436                      Wilson Synchrotron Lab & Ring  Engineering
# 437                                          Wing Hall  East Campus
# 438                                      Winter Garden  Plantations
# 439                                           Zeta Psi        Greek
# 440  Zucker Shrub Collection and Harris Lilac Colle...  Plantations
#
#                                               ImageURL  \
# 0
# 1    http://images.localist.com/images/main/busines...
# 2
# 3    http://images.localist.com/images/main/busines...
# 4
# ..                                                 ...
# 436  http://images.localist.com/photo/000/017/084/h...
# 437  http://images.localist.com/images/main/busines...
# 438  http://images.localist.com/photo/000/016/662/h...
# 439
# 440  http://images.localist.com/images/main/busines...
#
#                                   Address     Latitude     Longitude  \
# 0                                          42.44431073   -76.4878787
# 1                                          42.44409097  -76.48841178
# 2                                            42.441336     -76.47553
# 3                                          42.44033831  -76.48499927
# 4                                          42.44081657  -76.48497643
# ..                                    ...          ...           ...
# 436  161 Synchrotron Dr, Ithaca, NY 14850    42.445011    -76.472976
# 437         123 Wing Dr, Ithaca, NY 14850    42.446633    -76.471568
# 438                                        42.44910556  -76.47141389
# 439   534 Thurston Ave,. Ithaca, NY 14850    42.454121    -76.481827
# 440                                        42.45260833  -76.45610556
#
#                                                  Notes AKA
# 0    Dining (www.campuslife.cornell.edu/campuslife/...
# 1                                              Housing
# 2                                                  CIT
# 3
# 4                                            The Nines
# ..                                                 ...  ..
# 436                                  Wilson Laboratory
# 437
# 438                                        Plantations
# 439                                         Greek: IFC
# 440                                        Plantations
#
# [441 rows x 8 columns]

# %%
buildings_url = "https://en.wikipedia.org/wiki/List_of_Cornell_University_buildings#cite_note-1"
buildings_result = requests.get(buildings_url)
print(buildings_result)
# Out:
# <Response [200]>

# %%
with open("buildings.html", "w") as writer:
  writer.write(buildings_result.text)

with open("buildings.html", "r") as reader:
  html_source = reader.read()

page = BeautifulSoup(html_source, "html.parser")

# %%
rows = page.findChildren('tr')

# %%
names = []
images = []
architects = []
years = []
locations = []
notes = []

for row in rows[1:-30]:
    content = row.findChildren(['td'])

    if (content != []):
        # name
        if (content[0].findChildren('a') != []):
            name = content[0].findChildren('a')[0].string
            names.append(name)
            # print(name)
        else:
            name = content[0].string.strip('\n')
            names.append(name)
            # print(name)

        # image
        if (content[1].findChildren('img') != []):
            image = content[1].findChildren('img')[0]['srcset']\
                .split(',')[-1].split(' ')[1]\
                .strip('//').split('/300px')[0]\
                .replace('thumb/', '')
            images.append(image)
            # print(image)
        else:
            image = ''
            images.append(image)
            # print(image)

        # architect
        if (content[2].findChildren('a') != []):
            architect = content[2].findChildren('a')[0].string
            architects.append(architect)
            # print(architect)
        else:
            architect = content[2].string.strip('\n')
            architects.append(architect)
            # print(architect) 

        # years
        if (content[3].string != None):
            year = content[3].string.strip('\n')
            years.append(year)
            # print(year)
        else:
            year = ''
            years.append(year)
            # print(year)

        # location 
        if (content[4].string != None):
            location = content[4].string.strip('\n')
            locations.append(location)
            # print(location)
        else:
            location = ''
            locations.append(location)
            # print(location)

        # notes
        if (content[5].string != None):
            note = content[5].string.strip('\n')
            notes.append(note)
            # print(note)
        else:
            note = ''
            notes.append(note)
            # print(note)

# %%
wiki_buildings_df = pd.DataFrame(data = {"name": names,
                                         "image": images,
                                         "architect": architects,
                                         "year": years,
                                         "location": locations,
                                         "notes" : notes})

# %%
wiki_buildings_df
# Out:
#                            name  \
# 0    Andrew Dickson White House
# 1            Anabel Taylor Hall
# 2                 Atkinson Hall
# 3                   Bailey Hall
# 4              Baker Laboratory
# ..                          ...
# 165              Ganędagǫ: Hall
# 166               Toni Morrison
# 167          Barbara McClintock
# 168                     Hu Shih
# 169         Ruth Bader Ginsburg
#
#                                                  image  \
# 0    upload.wikimedia.org/wikipedia/commons/2/27/Co...
# 1    upload.wikimedia.org/wikipedia/commons/3/34/An...
# 2    upload.wikimedia.org/wikipedia/commons/2/24/At...
# 3    upload.wikimedia.org/wikipedia/commons/0/05/Co...
# 4    upload.wikimedia.org/wikipedia/commons/e/ef/Co...
# ..                                                 ...
# 165  upload.wikimedia.org/wikipedia/commons/0/09/Ga...
# 166  upload.wikimedia.org/wikipedia/commons/7/70/To...
# 167  upload.wikimedia.org/wikipedia/commons/c/cd/Ba...
# 168  upload.wikimedia.org/wikipedia/commons/9/99/Hu...
# 169  upload.wikimedia.org/wikipedia/commons/0/06/Ru...
#
#                         architect                    year  \
# 0            William Henry Miller                    1874
# 1     Starrett, Van Vleck & Marsh                    1953
# 2           Lake Flato Architects  Summer 2024 (expected)
# 3                 Green and Wicks                    1912
# 4    Arthur N. Gibb (B.Arch 1890)                    1921
# ..                            ...                     ...
# 165             ikon.5 Architects
# 166             ikon.5 Architects
# 167             ikon.5 Architects                    2022
# 168             ikon.5 Architects                    2022
# 169             ikon.5 Architects                    2022
#
#                  location                                              notes
# 0          Central Campus  Begun by Miller and finished by Babcock. Built...
# 1      548 College Avenue  Inside is a memorial to alumni killed in World...
# 2              Tower Road
# 3          Central Campus
# 4          Central Campus
# ..                    ...                                                ...
# 165   121 Triphammer Road
# 166       18 Sisson Place
# 167    224 Cradit Farm Dr                            103,835 sq ft; 311 beds
# 168  141 Program House Dr                            138,773 sq ft; 429 beds
# 169  155 Program House Dr                            162,849 sq ft; 504 beds
#
# [170 rows x 6 columns]
